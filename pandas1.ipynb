# %%
import pandas as pd

# %%
text_series = pd.Series(['maths','science','ml'])
text_series
# Out:
# 0      maths
# 1    science
# 2         ml
# dtype: object

# %%
text_series[1:3]
# Out:
# 1    science
# 2         ml
# dtype: object

# %%
 market = pd.read_csv('market_fact.csv')

# %%
market
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
market.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.3+ KB

# %%
market.shape
# Out:
# (8399, 10)

# %%
market.isnull().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
market.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
market.sort_values(by = 'Profit')
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 6952  Ord_5452  Prod_17  SHP_7621  Cust_1796  18888.00      0.09
# 4772  Ord_5047  Prod_17  SHP_7043  Cust_1714  19707.20      0.04
# 84    Ord_5232  Prod_17  SHP_7306  Cust_1758  21366.51      0.00
# 5454  Ord_3903  Prod_14  SHP_5417  Cust_1334   3457.99      0.05
# 5968  Ord_3073  Prod_14  SHP_4267  Cust_1142   3550.28      0.06
# ...        ...      ...       ...        ...       ...       ...
# 6765  Ord_5186  Prod_17  SHP_7247  Cust_1763  26095.13      0.03
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 2253  Ord_3143  Prod_14  SHP_4362  Cust_1170  28664.52      0.09
# 385   Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 6952               3 -14140.70          24.49                 0.39
# ...

# %%
market[30:36:2]
# Out:
#       Ord_id Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 30  Ord_2334  Prod_9  SHP_3203   Cust_931  129.10      0.00              27
# 32  Ord_2343  Prod_6  SHP_3215   Cust_931   76.16      0.04              12
# 34  Ord_5040  Prod_3  SHP_7033  Cust_1710  193.84      0.07              23
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 30  -59.82           4.99                 0.38
# 32  -24.03           5.20                 0.36
# 34 -117.10           8.94                 0.40

# %%
market.iloc[2:7,4:8]
# Out:
#      Sales  Discount  Order_Quantity   Profit
# 2  4701.69      0.00              26  1148.90
# 3  2337.89      0.09              43   729.34
# 4  4233.15      0.08              35  1219.87
# 5   164.02      0.03              23   -47.64
# 6    14.76      0.01               5     1.32

# %%
market.iloc[[2,5,7],[4,5,6]]
# Out:
#        Sales  Discount  Order_Quantity
# 2  4701.6900      0.00              26
# 5   164.0200      0.03              23
# 7  3410.1575      0.10              48

# %%
market = pd.read_csv('market_fact.csv')
customer = pd.read_csv('cust_dimen.csv')
product = pd.read_csv('prod_dimen.csv')

# %%
market.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
customer.head()
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %%
product.head()
# Out:
#   Product_Category            Product_Sub_Category Prod_id
# 0  OFFICE SUPPLIES          STORAGE & ORGANIZATION  Prod_1
# 1  OFFICE SUPPLIES                      APPLIANCES  Prod_2
# 2  OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES  Prod_3
# 3       TECHNOLOGY    TELEPHONES AND COMMUNICATION  Prod_4
# 4        FURNITURE              OFFICE FURNISHINGS  Prod_5

# %%
new_df = pd.merge(market,customer,how ='inner', on ='Cust_id')

# %%
master_df = pd.merge(new_df,product,how ='inner', on ='Prod_id')

# %%
master_df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.81      0.01
# 1     Ord_2978  Prod_16  SHP_4112  Cust_1088    305.05      0.04
# 2     Ord_5484  Prod_16  SHP_7663  Cust_1820    322.82      0.05
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314    459.08      0.04
# 4     Ord_4143  Prod_16  SHP_5771  Cust_1417    207.21      0.06
# ...        ...      ...       ...        ...       ...       ...
# 8394  Ord_5467  Prod_14  SHP_7639  Cust_1803   5964.19      0.10
# 8395   Ord_825  Prod_14  SHP_1132   Cust_247  27663.92      0.05
# 8396  Ord_5368  Prod_14  SHP_7497  Cust_1795  17279.62      0.04
# 8397  Ord_1765  Prod_14  SHP_2446   Cust_595  14647.26      0.07
# 8398  Ord_3610  Prod_14  SHP_4998  Cust_1266   1759.65      0.06
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
master_df.to_csv('master_data.csv',index = False)

# %%
master_df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.81      0.01
# 1     Ord_2978  Prod_16  SHP_4112  Cust_1088    305.05      0.04
# 2     Ord_5484  Prod_16  SHP_7663  Cust_1820    322.82      0.05
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314    459.08      0.04
# 4     Ord_4143  Prod_16  SHP_5771  Cust_1417    207.21      0.06
# ...        ...      ...       ...        ...       ...       ...
# 8394  Ord_5467  Prod_14  SHP_7639  Cust_1803   5964.19      0.10
# 8395   Ord_825  Prod_14  SHP_1132   Cust_247  27663.92      0.05
# 8396  Ord_5368  Prod_14  SHP_7497  Cust_1795  17279.62      0.04
# 8397  Ord_1765  Prod_14  SHP_2446   Cust_595  14647.26      0.07
# 8398  Ord_3610  Prod_14  SHP_4998  Cust_1266   1759.65      0.06
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
master = pd.read_csv('master_data.csv')

# %%
master.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01              23
# 1  Ord_2978  Prod_16  SHP_4112  Cust_1088  305.05      0.04              27
# 2  Ord_5484  Prod_16  SHP_7663  Cust_1820  322.82      0.05              35
# 3  Ord_3730  Prod_16  SHP_5175  Cust_1314  459.08      0.04              34
# 4  Ord_4143  Prod_16  SHP_5771  Cust_1417  207.21      0.06              24
#
#    Profit  Shipping_Cost  Product_Base_Margin        Customer_Name  \
# 0  -30.51           3.60                 0.56        AARON BERGMAN
# 1   23.12           3.37                 0.57        AARON HAWKINS
# 2  -17.58           3.98                 0.56         ADRIAN SHAMI
# 3   61.57           3.14                 0.60  ALEKSANDRA GANNAWAY
# 4  -78.64           6.14                 0.59         ALLEN ARMOLD
#
#         Province    Region Customer_Segment Product_Category  \
# ...

# %%
master.loc[master['Profit'] < 0,['Prod_id','Sales','Profit']]
# Out:
#       Prod_id     Sales   Profit
# 0     Prod_16    136.81   -30.51
# 2     Prod_16    322.82   -17.58
# 4     Prod_16    207.21   -78.64
# 5     Prod_16     95.09   -13.53
# 6     Prod_16    182.47    -3.18
# ...       ...       ...      ...
# 8388  Prod_14  19109.61  -379.29
# 8390  Prod_14  27875.54  -635.69
# 8392  Prod_14    614.14  -735.27
# 8395  Prod_14  27663.92  -391.92
# 8398  Prod_14   1759.65 -2213.75
#
# [4264 rows x 3 columns]

# %%
master[master['Profit'] < 0 & (master['Sales'] > 100)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.81      0.01
# 2     Ord_5484  Prod_16  SHP_7663  Cust_1820    322.82      0.05
# 4     Ord_4143  Prod_16  SHP_5771  Cust_1417    207.21      0.06
# 5     Ord_4796  Prod_16  SHP_6686  Cust_1659     95.09      0.09
# 6     Ord_1854  Prod_16  SHP_2548   Cust_727    182.47      0.05
# ...        ...      ...       ...        ...       ...       ...
# 8388   Ord_508  Prod_14   SHP_686   Cust_186  19109.61      0.10
# 8390   Ord_546  Prod_14   SHP_858   Cust_198  27875.54      0.00
# 8392  Ord_3721  Prod_14  SHP_5162  Cust_1309    614.14      0.09
# 8395   Ord_825  Prod_14  SHP_1132   Cust_247  27663.92      0.05
# 8398  Ord_3610  Prod_14  SHP_4998  Cust_1266   1759.65      0.06
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
master[master['Profit'] < 0 & (master['Sales'] > 100)].sort_values(by = 'Profit', ascending = False)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 360    Ord_416  Prod_13   SHP_560   Cust_139     46.97      0.03
# 3503  Ord_2575  Prod_12  SHP_3529   Cust_990     14.96      0.02
# 6075  Ord_2370   Prod_7  SHP_4538  Cust_1200     34.93      0.04
# 621   Ord_1246  Prod_13  SHP_1722   Cust_468     27.06      0.00
# 4781    Ord_38   Prod_5    SHP_50    Cust_29    118.97      0.09
# ...        ...      ...       ...        ...       ...       ...
# 8374  Ord_3073  Prod_14  SHP_4267  Cust_1142   3550.28      0.06
# 8369  Ord_3903  Prod_14  SHP_5417  Cust_1334   3457.99      0.05
# 2888  Ord_5232  Prod_17  SHP_7306  Cust_1758  21366.51      0.00
# 3080  Ord_5047  Prod_17  SHP_7043  Cust_1714  19707.20      0.04
# 3174  Ord_5452  Prod_17  SHP_7621  Cust_1796  18888.00      0.09
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin  \
# 360                8     -0.01           1.20                 0.55
# ...

# %%
import numpy as np
import pandas as pd

# %%
series = pd.Series(np.array(['ram','sita']), index=[1,2])

# %%
series
# Out:
# 1     ram
# 2    sita
# dtype: object

# %%
series2 = pd.Series({'x':4, 'y':7. , 'z':3.})

# %%
series2
# Out:
# x    4.0
# y    7.0
# z    3.0
# dtype: float64

# %%
abc = pd.DataFrame([1,2,3,4,5])

# %%
abc
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
data1 = {'Name':['ab','bb'],
         'Role':['admin','sec'],
         'class':[5,7] }

# %%
data1
# Out:
# {'Name': ['ab', 'bb'], 'Role': ['admin', 'sec'], 'class': [5, 7]}

# %%
sd = pd.DataFrame(data1)

# %%
sd
# Out:
#   Name   Role  class
# 0   ab  admin      5
# 1   bb    sec      7

# %%
q = pd.Series(data1)

# %%
q
# Out:
# Name         [ab, bb]
# Role     [admin, sec]
# class          [5, 7]
# dtype: object
